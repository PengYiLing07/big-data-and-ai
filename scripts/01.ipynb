# %% [markdown]
# # 第 1 讲 · 环境自检
#
# 对应《0917课堂要点》—— 创建 .ipynb 文件并运行。
#
# 逐格运行：点上方“运行全部”，或按 Shift+Enter 逐格执行。

# %%
print("你好，这是我在 VS Code 里创建并运行的第一个 .ipynb 文件。")

import sys, platform
print("Python 版本：", sys.version.split()[0])
print("解释器路径：", sys.executable)
print("操作系统：  ", platform.system(), platform.release())
# Out:
# 你好，这是我在 VS Code 里创建并运行的第一个 .ipynb 文件。
# Python 版本： 3.12.10
# 解释器路径： D:\大数据与人工智能\big-data-and-ai\.venv\Scripts\python.exe
# 操作系统：   Windows 11

# %% [markdown]
# ## 设置 pip 为国内源
#
# 下面两格验证 pip 已指向清华镜像源，下载时不走官方源。

# %%
# %pip install --upgrade pip
# Out:
# Looking in indexes: https://mirrors.tuna.tsinghua.edu.cn/pypi/web/simple
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip config get global.index-url
# Out:
# https://mirrors.tuna.tsinghua.edu.cn/pypi/web/simple

# %% [markdown]
# ## 小结
#
# - .py 与 .ipynb 都能创建并运行
# - pip 已指向国内源，装包速度正常
# - 下一步：把 scripts/ 目录提交到 GitHub 远程仓库
